00_17.mp4',
    # '/share/project/cwm/xiuyu.yang/work/dev6/DiffusionAsShader/outputs3/eval_cirasim_rt1_traj-image-condfull_480-320_finetune_2b_20k/eval_15637_32_17.mp4',
    # '/share/project/cwm/xiuyu.yang/work/dev6/DiffusionAsShader/outputs3/eval_cirasim_rt1_traj-image-condfull_480-320_finetune_2b_20k/eval_17548_00_17.mp4',
    # '/share/project/cwm/xiuyu.yang/work/dev6/DiffusionAsShader/outputs3/eval_cirasim_rt1_traj-image-condfull_480-320_finetune_2b_20k/eval_20816_00_17.mp4',
    # '/share/project/cwm/xiuyu.yang/work/dev6/DiffusionAsShader/outputs3/eval_cirasim_rt1_traj-image-condfull_480-320_finetune_2b_20k/eval_21690_32_17.mp4',
    # '/share/project/cwm/xiuyu.yang/work/dev6/DiffusionAsShader/outputs3/eval_cirasim_rt1_traj-image-condfull_480-320_finetune_2b_20k/eval_23895_00_17.mp4',
    # '/share/project/cwm/xiuyu.yang/work/dev6/DiffusionAsShader/outputs3/eval_cirasim_rt1_traj-image-condfull_480-320_finetune_2b_20k/eval_67370_00_17.mp4',
]


save_folder = os.path.join('demo_videos', 'droid_2')
os.makedirs(save_folder, exist_ok=True)
# merge gt and pred videos

for pred_path in tqdm(pred_paths):
    episode_id = os.path.basename(pred_path).lstrip('eval_')
    gt_path = os.path.join(bridge1_gt_folder, episode_id)
    # gt_path = os.path.join(droid_gt_folder, episode_id)
    # gt_path = os.path.join(rt1_gt_folder, episode_id)

    pred_vr = VideoReader(pred_path)
    pred_video = pred_vr.get_batch(range(len(pred_vr))).asnumpy().astype(np.float32)

    try:
        gt_vr = VideoReader(gt_path)
        gt_video = gt_vr.get_batch(range(len(gt_vr))).asnumpy().astype(np.float32)
    except:
        gt_video = pred_video

    fps = 8
    h, w, _ = pred_video[0].shape

    combined_video = []
    if 'droid' in save_folder:
        pred_video = pred_video[4:]
    for pred_frame, gt_frame in tqdm(zip(pred_video, gt_video)):

        pred_frame_ = Image.fromarray(pred_frame.astype(np.uint8)).convert('RGB')
        combined_frame = pred_frame
        # gt_frame_ = Image.fromarray(gt_frame.astype(np.uint8))

        # combined_frame = Image.new('RGB', (w * 2, h))
        # combined_frame.paste(pred_frame_, (0, 0, w, h))
        # combined_frame.paste(gt_frame_, (w, 0, w * 2, h))
        combined_frame = Image.new('RGB', (w, h))
        combined_frame.paste(pred_frame_, (0, 0, w, h))
        combined_video.append(combined_frame)

    save_path = os.path.join(save_folder, episode_id)
    export_to_video(combined_video, save_path, fps=fps)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s][16:15:58] /github/workspace/src/video/video_reader.cc:83: ERROR opening: /share/project/cwm/xiuyu.yang/work/dev6/DiffusionAsShader/data_old/bridge/embeddings_320_480_sliced_full/val/videos/00001_00_29.mp4, No such file or directory
# 25it [00:00, 1755.79it/s]
#   4%|▎         | 1/27 [00:00<00:05,  4.80it/s][16:15:58] /github/workspace/src/video/video_reader.cc:83: ERROR opening: /share/project/cwm/xiuyu.yang/work/dev6/DiffusionAsShader/data_old/bridge/embeddings_320_480_sliced_full/val/videos/00004_00_29.mp4, No such file or directory
# 25it [00:00, 1725.17it/s]
#   7%|▋         | 2/27 [00:00<00:04,  5.11it/s][16:15:58] /github/workspace/src/video/video_reader.cc:83: ERROR opening: /share/project/cwm/xiuyu.yang/work/dev6/DiffusionAsShader/data_old/bridge/embeddings_320_480_sliced_full/val/videos/00020_00_29.mp4, No such file or directory
# 25it [00:00, 1724.26it/s]
# ...
